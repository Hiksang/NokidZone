# %%
import os
import sys
import urllib.request
import json
import pandas as pd
import csv

# %%
client_id = "sjLpa9C1xgZo0gqKTL3Z"
client_secret = "FXyffvjqWF"

encText = urllib.parse.quote("스터디 카페")

# %%
import requests
from urllib.parse import urlparse
 
keyword = "스터디카페"
url = "https://openapi.naver.com/v1/search/blog?query=" + keyword
result = requests.get(urlparse(url).geturl(),
                      headers={"X-Naver-Client-Id": client_id,
                             "X-Naver-Client-Secret":client_secret})
json_obj = result.json()
print(json_obj)
type(json_obj)
# Out:
# {'lastBuildDate': 'Sun, 30 Oct 2022 13:57:23 +0900', 'total': 922300, 'start': 1, 'display': 10, 'items': [{'title': '상도동 <b>스터디카페</b> 깔끔하고 시설 좋은 프리미엄 스카', 'link': 'https://blog.naver.com/like5183/222892248344', 'description': '지난번에 제가 요즘에는 퇴근 후 테니스 수업 전까지 3~4시간 텀이 있는데 예전에는 남는 시간에 카페나... 상도동 <b>스터디카페</b>의 스터디존을 보여드릴게요! 저는 평일 3시 좀 넘어서 방문한거라 아직은 학생들이... ', 'bloggername': '@ zeonining', 'bloggerlink': 'blog.naver.com/like5183', 'postdate': '20221005'}, {'title': '도봉 방학동<b>스터디카페</b> 초월방학점 이용 및 추천후기', 'link': 'https://blog.naver.com/estjane/222909713562', 'description': '초월 <b>스터디카페</b>는 크게 휴게존 / 포커스존 / 카페존 / 스터디룸 네 구역으로 나뉘어 있는데요, 순서대로 소개해볼게요:) 휴게존 입장하면 바로 휴게존인데요, 깔끔함 그잡채..무인 맞나 싶을 정도. 아이스티... ', 'bloggername': '엣티제인', 'bloggerlink': 'blog.naver.com/estjane', 'postdate': '20221025'}, {'title': '<b>스터디카페</b> 창업비용 이제는 때가 아니다?', 'link': 'https://blog.naver.com/hyunjae2828/222913316386', 'description': '<b>스터디카페</b> 창업비용에 대해서 알아보고 있는 분들이라면 자신이 어떤 브랜드를 선택해야 하는지 그 고민에 가장 많이 빠져 계실 듯 합니다. 특히 카페 시
# ...

# %%
def call(keyword, start):
    encText = urllib.parse.quote(keyword)
    url = "https://openapi.naver.com/v1/search/blog?query="+encText+"&sort=sim&display=100&start="+str(start)
    result = requests.get(url=url, headers={"X-Naver-Client-Id":client_id,"X-Naver-Client-Secret":client_secret})
    print(result)  # Response [200]
    return result.json()

# %%
#call("스터디카페", 10)

# %%
def results(keyword):
    list = []
    for num in range(0,10):
        list = list + call(keyword, num * 110 + 1)['items'] 
    return list

# %%
listt = []
result = results('스터디카페')
listt = listt+result

file = open('studycafe_blog.json','w+')
file.write(json.dumps(listt))


df = pd.read_json('studycafe_blog.json')
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
import re

def clean_html(x):
    x = re.sub("\&\w*\;","",x)
    x = re.sub("<.*?>","",x)
    return x

# %%
df['title'] = df['title'].apply(lambda x: clean_html(x))
df['description'] = df['description'].apply(lambda x: clean_html(x))

# %%
df

# %%
#df.to_csv('studycafe1.csv',encoding='cp949')
df.to_csv('crawling_blog.csv',encoding='utf-8-sig',index=False)

# %%
import requests
from urllib.parse import urlparse
 
keyword = '"노키즈존"'
url = "https://openapi.naver.com/v1/search/blog?query=" + keyword
result = requests.get(urlparse(url).geturl(),
                      headers={"X-Naver-Client-Id": client_id,
                             "X-Naver-Client-Secret":client_secret})
json_obj = result.json()
print(json_obj)
type(json_obj)
# Out:
# {'lastBuildDate': 'Sun, 30 Oct 2022 13:57:58 +0900', 'total': 132070, 'start': 1, 'display': 10, 'items': [{'title': '<b>노키즈존</b> 김포 카페 아보고가 베이커리', 'link': 'https://blog.naver.com/dmsp3535/222667536709', 'description': '오픈한지 얼마 되지 않은 김포 카페 아보고가 사실 오픈전부터 엄청 기대했던 곳인데 <b>노키즈존</b>이라는... 인스타에서 오픈 소식 보고 얼마나 가보고 싶었는지 몰라요 사실 아기 낳기 전에는 조용한 <b>노키즈존</b>을... ', 'bloggername': 'GRACE&apos;s lov diary', 'bloggerlink': 'blog.naver.com/dmsp3535', 'postdate': '20220308'}, {'title': '동대문 BLT 스테이크 런치코스 Sharing Lunch 후기 (<b>노키즈존</b>)', 'link': 'https://blog.naver.com/snsii/222911446559', 'description': '귀여운 촛불까지 ㅎㅎ 후식 음료로는 커피나 TWG 홍차 중 선택 가능한데 아이스라떼로 시킬 수 있어서 너무 다행이었음 (라떼 최고) 정말 아쉬운 건 10세 이상부터만 출입되는 <b>노키즈존</b>이라는거; 이거... ', 'bloggername': 'Si day book', 'bloggerlink': 'blog.naver.com/snsii', 'postdate': '20221026'}, {'title': '부산 바다뷰 대형 카페 송정 코랄라니 루프탑 <b>노키즈존</b>', 'link': 'https://blog.naver.com/namnaraum/222680035496', 'description': '부산 바다뷰 대형 카페 송정 코랄라니 루프탑 <b>노키즈존</b> 오랜만에 핫플, 예쁜 카페를 다녀왔다. 그것도... 
# ...

# %%
def call(keyword, start):
    encText = urllib.parse.quote(keyword)
    url = "https://openapi.naver.com/v1/search/blog?query="+encText+"&sort=sim&display=100&start="+str(start)
    result = requests.get(url=url, headers={"X-Naver-Client-Id":client_id,"X-Naver-Client-Secret":client_secret})
    print(result)  # Response [200]
    return result.json()

# %%
def results(keyword):
    list = []
    for num in range(0,10):
        list = list + call(keyword, num * 110 + 1)['items'] 
    return list

# %%
listt = []
result = results('"노키즈존"')
listt = listt+result

file = open('studycafe_morethan.json','w+')
file.write(json.dumps(listt))


df = pd.read_json('studycafe_morethan.json')
# print(df)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
import re

def clean_html(x):
    x = re.sub("\&\w*\;","",x)
    x = re.sub("<.*?>","",x)
    return x

# %%
df['title'] = df['title'].apply(lambda x: clean_html(x))
df['description'] = df['description'].apply(lambda x: clean_html(x))

# %%
df
# Out:
#                                          title  \
# 0                         노키즈존 김포 카페 아보고가 베이커리
# 1    동대문 BLT 스테이크 런치코스 Sharing Lunch 후기 (노키즈존)
# 2                부산 바다뷰 대형 카페 송정 코랄라니 루프탑 노키즈존
# 3              워커힐 더글라스 하우스 노키즈존 주차정보 및 체크인 꿀팁
# 4        노키즈존 설정, 애견 동반 허용 어떻게 해야 할지 고민 끝!...
# ..                                         ...
# 995            제대로 된 딤섬 집을 찾다! (ft. 노키즈존으로 변경)
# 996           [칠곡]노키즈존, 예쁜 카페, 칠곡 모노블(MONOVEL)
# 997     김포 아보고가 (feat : 0세 아기는 입장 가능한 노키즈존 카페)
# 998       강원도 춘천 황금박쥐캠핑장 이용후기 (1박 비용, 노키즈존...
# 999      분당 카페 모아니 : 서울근교 전망좋은 대형카페 , 주차, 노키즈존
#
#                                                 link  \
# 0       https://blog.naver.com/dmsp3535/222667536709
# 1          https://blog.naver.com/snsii/222911446559
# 2      https://blog.naver.com/namnaraum/222680035496
# 3      https://blog.naver.com/jjiingnii/222877547434
# 4     https://blog.naver.com/yestv_blog/222905630785
# ..                                               ...
# ...

# %%
#df.to_csv('studycafe1.csv',encoding='cp949')
df.to_csv('crawling_blog.csv',encoding='utf-8-sig',index=False)

# %% [markdown]
# ### 카페

# %%
def call(keyword, start):
    encText = urllib.parse.quote(keyword)
    url = "https://openapi.naver.com/v1/search/cafearticle.json?query="+encText+"&sort=sim&start="+str(start)
    result = requests.get(url=url, headers={"X-Naver-Client-Id":client_id,"X-Naver-Client-Secret":client_secret})
    print(result)  # Response [200]
    return result.json()

# %%
#call('스터디카페',10)

# %%
def results(keyword):
    list = []
    for num in range(0,10):
        list = list + call(keyword, num * 110 + 1)['items'] 
    return list

# %%
results('노키즈존')
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# [{'title': '<b>노키즈존</b>에 대하여',
#   'link': 'http://cafe.naver.com/sjmoms/1908341',
#   'description': '그런데 들어가자마자 사장분이신 듯한 아주머니가 나오시더니 아이들을 보고는 여기 <b>노키즈존</b>이에요... 했더니 아마 자기 없을 때 그냥 들여 보내 준 것 같다며 여기 방침이 원래 <b>노키즈존</b>이에요~ 하시더라구요. 제가 너무... ',
#   'cafename': '성동구 중구 엄마들 모임',
#   'cafeurl': 'https://cafe.naver.com/sjmoms'},
#  {'title': '<b>노키즈존</b>카페요',
#   'link': 'http://cafe.naver.com/imsanbu/63197045',
#   'description': '카페나 이런데가면 <b>노키즈존</b>이 있는데 아기는 다 가면 안되는거죠? 사진 찍어주러 잠깐 갓다오는것도 안되나요? 어디까지 얼만큼 가능한가 궁금하네요 <b>노키즈존</b>이라 단어에 접근 자체가 조심스러워서 근처 가보지도... ',
#   'cafename': '맘스홀릭 베이비 (300만 엄마들의 임신...',
#   'cafeurl': 'https://cafe.naver.com/imsanbu'},
#  {'title': '너무 고민입니다.. <b>노키즈존</b>..',
#   'link': 'http://cafe.naver.com/newhd/616911',
# ...

# %%
listt = []
result = results('노키즈존')
listt = listt+result

file = open('studycafe_cafe.json','w+')
file.write(json.dumps(listt))


df = pd.read_json('studycafe_cafe.json')
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
df
# Out:
#                               title  \
# 0                  <b>노키즈존</b>에 대하여
# 1                    <b>노키즈존</b>카페요
# 2          너무 고민입니다.. <b>노키즈존</b>..
# 3           <b>노키즈존</b> 아파트 생겼으면...
# 4               이제 <b>노키즈존</b> 아니래요
# ..                              ...
# 95            낮에도 절간마냥 조용한 캠핑장 왔습니다
# 96              <b>노키즈존</b>.. 씁쓸하네요
# 97  황리단길 <b>노키즈존</b> 아닌 곳 추천부탁드려요!!
# 98        <b>노키즈존</b>.. 어떻게 생각하시나요?
# 99       <b>노키즈존</b>에 대한 여론... 슬프네요
#
#                                           link  \
# 0         http://cafe.naver.com/sjmoms/1908341
# 1       http://cafe.naver.com/imsanbu/63197045
# 2           http://cafe.naver.com/newhd/616911
# 3      http://cafe.naver.com/ihatenoise/291880
# 4          http://cafe.naver.com/bgmama/346173
# ..                                         ...
# 95  http://cafe.naver.com/campingfirst/2492076
# 96      http://cafe.naver.com/jinjululu/861167
# 97    http://cafe.naver.com/phmomstory/2556585
# ...

# %%
#df.to_csv('studycafe1.csv',encoding='cp949')
df.to_csv('crawling_morethan.csv',encoding='utf-8-sig',index=False)

# %%
import re

def clean_html(x):
    x = re.sub("\&\w*\;","",x)
    x = re.sub("<.*?>","",x)
    return x

# %%
df['title'] = df['title'].apply(lambda x: clean_html(x))
df['description'] = df['description'].apply(lambda x: clean_html(x))

# %%
df['title'] = df['title'].apply(lambda x: clean_html(x))
df['description'] = df['description'].apply(lambda x: clean_html(x))

# %%
#df.to_csv('studycafe1.csv',encoding='cp949')
df.to_csv('crawling_cafe.csv',encoding='utf-8-sig',index=False)
